# %%
name = "박수현"
age = 29
temperature = 36.8
high_blood_pressure = True

print("이름 = \"", name, "\"")
print("나이 = ", age)
print("체온 = ", temperature)
print("고혈압 = ", high_blood_pressure)

print(type(name))
print(type(age))
print(type(temperature))
print(type(high_blood_pressure))
# Out:
# 이름 = " 박수현 "
# 나이 =  29
# 체온 =  36.8
# 고혈압 =  True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
