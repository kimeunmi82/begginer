# %%
# 첫 파이썬 코드
print("Hellow AI Healthcare!")
print(2026)
print("올해는", 2026,"년 입니다.")
# 주석당기
# 이 줄은 실행되지 않아요.
# Out:
# Hellow Ai Healthcare!
# 2026
# 올해는 2026 년 입니다.

# %%
# 자기소개
print("My name is Tov!")
print("I am 45 years old")
print("I like sushi")
# Out:
# My name is Tov!
# I am 45 years old
# I like sushi
