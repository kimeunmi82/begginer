# %%
for i in range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
names = ["지민", "수아", "하늘", "민재"]

for name in names:
  print("안녕하세요, ",name,"님")
# Out:
# 안녕하세요,  지민 님
# 안녕하세요,  수아 님
# 안녕하세요,  하늘 님
# 안녕하세요,  민재 님
